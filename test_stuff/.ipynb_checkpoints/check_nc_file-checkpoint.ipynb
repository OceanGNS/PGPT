# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
import gsw as sw
import xarray as xr

# Path containing python functions
glidertoolbox_path = ['/Users/research/Documents/GitHub/gliderProcessing/glider_processing_scripts/']

sys.path.append(glidertoolbox_path[0])
from functions import c2salinity,p2depth,dm2d,rad2deg,O2freshtosal,range_check,correctDR,findProfiles

# %%
nc_path = '/Users/research/Documents/GitHub/gliderProcessing/glider_data/echo/echo_20230113/delayed/nc/'
nc_file = ['echo-2023-012-0-0_delayed.nc','delayed_timeseries.nc']

# %%
gl = xr.open_dataset(nc_path+nc_file[1])

# %%
gl
# Out:
# <xarray.Dataset>
# Dimensions:                          (timestamp: 19304)
# Coordinates:
#   * timestamp                        (timestamp) float64 1.674e+09 ... 1.674e+09
# Data variables: (12/183)
#     c_ballast_pumped                 (timestamp) float64 ...
#     c_battpos                        (timestamp) float64 ...
#     c_de_oil_vol                     (timestamp) float64 ...
#     c_fin                            (timestamp) float64 ...
#     c_gps_on                         (timestamp) float64 ...
#     c_heading                        (timestamp) float64 ...
#     ...                               ...
#     sci_water_depth                  (timestamp) float64 ...
#     oxygen_concentration             (timestamp) float64 ...
#     lon_corrected                    (timestamp) float64 ...
#     lat_corrected                    (timestamp) float64 ...
#     profile_index                    (timestamp) float64 ...
#     profile_direction                (timestamp) float64 ...

# %%
#plt.plot(gl['m_depth'],gl['sci_water_depth'],'.')
